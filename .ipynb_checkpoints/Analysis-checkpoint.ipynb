# %% [markdown]
# # Analysis of time series data

# %%
# packeges
import pandas as pd
import numpy as np
import seaborn as sns
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Linear regression
from sklearn.linear_model import LinearRegression

# AR model
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.ar_model import AutoReg

# ARIMA
from pmdarima.arima.utils import ndiffs

# %% [markdown]
# ## DATA

# %%
# load data from github
url = 'https://raw.githubusercontent.com/Fdvanleeuwen/Energy-Price-Forecasting/main/Data/PJME_hourly.csv'
df = pd.read_csv(url)
df = df.set_index('Datetime') # set the index as the Datetime column
df.index = pd.to_datetime(df.index) # change type of data of index to datetime

# %%
# inspect the data
df.head(5)
# Out:
#                      PJME_MW
# Datetime
# 2002-12-31 01:00:00  26498.0
# 2002-12-31 02:00:00  25147.0
# 2002-12-31 03:00:00  24574.0
# 2002-12-31 04:00:00  24393.0
# 2002-12-31 05:00:00  24860.0

# %%
# plot the full data
df.plot(figsize = (14,4), title = 'PJME Eergy Use in MW')

# plot a weeks worth to see the variablity
df.loc[(df.index > '01-01-2010') & (df.index < '01-08-2010')] \
    .plot(figsize=(15, 5), title='Week Of Data')
plt.show()

# %% [markdown]
# ## Train/Test set

# %%
# training data is approx 80% of data, test is 20%
train = df.loc[df.index < '01-01-2015']
test = df.loc[df.index >= '01-01-2015']

# plot when the devide in the data is
fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline('01-01-2015', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %% [markdown]
# ## Feature creation

# %%
# create a funciton that makes features based

def create_features(df):
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

# %%
df = create_features(df)

# check out the new predictors
df.head(5)
# Out:
#                      PJME_MW  hour  dayofweek  quarter  month  year  \
# Datetime
# 2002-12-31 01:00:00  26498.0     1          1        4     12  2002
# 2002-12-31 02:00:00  25147.0     2          1        4     12  2002
# 2002-12-31 03:00:00  24574.0     3          1        4     12  2002
# 2002-12-31 04:00:00  24393.0     4          1        4     12  2002
# 2002-12-31 05:00:00  24860.0     5          1        4     12  2002
#
#                      dayofyear  dayofmonth  weekofyear
# Datetime
# 2002-12-31 01:00:00        365          31           1
# 2002-12-31 02:00:00        365          31           1
# 2002-12-31 03:00:00        365          31           1
# 2002-12-31 04:00:00        365          31           1
# 2002-12-31 05:00:00        365          31           1

# %% [markdown]
# ## Visualize our Feature / Target Relationship

# %%
# Variation per month
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='month', y='PJME_MW', palette='Blues')
ax.set_title('MW by Month')
plt.show()

# Variation per day
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='hour', y='PJME_MW')
ax.set_title('MW by Hour')
plt.show()

# %% [markdown]
# ## Models

# %%
# create seperate data set for the x and y values
train = create_features(train)
test = create_features(test)

FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
TARGET = 'PJME_MW'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %% [markdown]
# ### Linear regression

# %%
# fit model
m1 = LinearRegression()
m1.fit(X_train, y_train)

# predict
pred_lr = m1.predict(X_test)
# Out:
# array([27030.3650643 , 26852.8026142 , 27315.03525325, ...,
#        38934.62217406, 39396.85481312, 28152.79541478])

# %% [markdown]
# ### AR

# %%
# Check for stationarity of the time-series data
# We will look for p-value. In case, p-value is less than 0.05, the time series
# data can said to have stationarity

df_stationarityTest = adfuller(df['PJME_MW'], autolag='AIC')

# Check the value of p-value
print("P-value: ", df_stationarityTest[1])

# Next step is to find the order of AR model to be trained
# for this, we will plot partial autocorrelation plot to assess
# the direct effect of past data on future data
pacf = plot_acf(df['PJME_MW'], lags=200)
pacf = plot_pacf(df['PJME_MW'], lags=200)

# Instantiate and fit the AR-200 model with training data

ar_model = AutoReg(y_train, lags=10).fit()

# predict
pred_ar = ar_model.predict(start=len(y_train), end=(len(df)-1), dynamic=False)
# Out:
# P-value:  2.022124508152674e-30
# /Users/florian/opt/miniconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# /Users/florian/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/florian/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/florian/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/florian/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)

# %% [markdown]
# ### ARIMA

# %%
## Adf Test
ndiffs(df['PJME_MW'], test='adf')  # 2

# KPSS test
ndiffs(df['PJME_MW'], test='kpss')  # 0

# PP test:
ndiffs(df['PJME_MW'], test='pp')  # 2
# Out:
# 0

# %%
# 1,1,2 ARIMA Model
model = ARIMA(df['PJME_MW'], order=(1,1,2))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [64], in <cell line: 2>()
#       1 # 1,1,2 ARIMA Model
# ----> 2 model = ARIMA(df['PJME_MW'], order=(1,1,2))
#       3 model_fit = model.fit(disp=0)
#       4 print(model_fit.summary())
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:45, in ARIMA.__init__(self, *args, **kwargs)
#      44 def __init__(self, *args, **kwargs):
# ---> 45     super().__init__(*args, **kwargs)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/statsmodels/tsa/arima_model.py:29, in ARMA.__init__(self, *args, **kwargs)
#      28 def __init__(self, *args, **kwargs):
# ---> 29     raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %% [markdown]
# ### Gradient Boosting

# %%
# check how well the models run

mean_squared_error(y_test, test['LR prediction'])
